# %%
# Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #  Read Data

# %%
df= pd.read_excel(r"C:\Users\shivani\Downloads\19. Flight_price.xlsx")

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %%
df.shape
# Out:
# (10683, 11)

# %%
df.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %%
df['Date_of_Journey']= pd.to_datetime(df['Date_of_Journey'],format='%d/%m/%Y')

# %%
df['Dep_Time']= pd.to_datetime(df['Dep_Time'],format='%H:%M')

# %%
df['Journey_Date']= df['Date_of_Journey'].dt.day
df['Journey_Month']= df['Date_of_Journey'].dt.month
df['Journey_Year'] = df['Date_of_Journey'].dt.year

# %%
df.drop(columns=['Date_of_Journey'],axis=1,inplace=True)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL
#
#              Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  \
# 0 1900-01-01 22:20:00  01:10 22 Mar   2h 50m    non-stop         No info
# 1 1900-01-01 05:50:00         13:15   7h 25m     2 stops         No info
# 2 1900-01-01 09:25:00  04:25 10 Jun      19h     2 stops         No info
# 3 1900-01-01 18:05:00         23:30   5h 25m      1 stop         No info
# 4 1900-01-01 16:50:00         21:35   4h 45m      1 stop         No info
#
#    Price  Journey_Date  Journey_Month  Journey_Year
# 0   3897            24              3          2019
# 1   7662             1              5          2019
# 2  13882             9              6          2019
# 3   6218            12              5          2019
# 4  13302             1              3          2019

# %%
df['Departure_Hour']= df['Dep_Time'].dt.hour
df['Departure_Minute']= df['Dep_Time'].dt.minute

# %%
df.drop(columns=['Dep_Time'],axis=1,inplace=True)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route  Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  04:25 10 Jun
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR         23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL         21:35
#
#   Duration Total_Stops Additional_Info  Price  Journey_Date  Journey_Month  \
# 0   2h 50m    non-stop         No info   3897            24              3
# 1   7h 25m     2 stops         No info   7662             1              5
# 2      19h     2 stops         No info  13882             9              6
# 3   5h 25m      1 stop         No info   6218            12              5
# 4   4h 45m      1 stop         No info  13302             1              3
#
#    Journey_Year  Departure_Hour  Departure_Minute
# 0          2019              22                20
# 1          2019               5                50
# 2          2019               9                25
# 3          2019              18                 5
# 4          2019              16                50

# %%
df['Arrival_Time']
# Out:
# 0        01:10 22 Mar
# 1               13:15
# 2        04:25 10 Jun
# 3               23:30
# 4               21:35
#              ...
# 10678           22:25
# 10679           23:20
# 10680           11:20
# 10681           14:10
# 10682           19:15
# Name: Arrival_Time, Length: 10682, dtype: object

# %%
df['Arrival_Hour']= pd.to_datetime(df['Arrival_Time']).dt.hour
df['Arrival_Minute']= pd.to_datetime(df['Arrival_Time']).dt.minute

# %%
df.drop(columns=['Arrival_Time'],axis=1,inplace=True)

# %%
"2h 50m".split()
# Out:
# ['2h', '50m']

# %%
duration = list(df['Duration'])


for i in range(len(duration)):
    if len(duration[i].split()) != 2:
        if "h" in duration[i]:
            duration[i] = duration[i].strip() + " 0m"
        else:
            duration[i] = "0h " + duration[i].strip()


duration_hours = []
duration_mins = []

for i in range(len(duration)):
    hours = int(duration[i].split(sep="h")[0])
    mins = int(duration[i].split(sep="h")[1].strip(" m"))
    duration_hours.append(hours)
    duration_mins.append(mins)

# %%
df["Duration_hours"]= duration_hours
df["Duration_minutes"]= duration_mins

# %%
df.drop(columns=['Duration','Route','Additional_Info'],axis=1,inplace=True)

# %%
df['Total_Stops'].value_counts()
# Out:
# Total_Stops
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: count, dtype: int64

# %%
df['Total_Stops']=df['Total_Stops'].map({"non-stop":0,"1 stop":1,"2 stops":2,"3 stops":3,"4 stops":4})

# %%
df.head()
# Out:
#        Airline    Source Destination  Total_Stops  Price  Journey_Date  \
# 0       IndiGo  Banglore   New Delhi            0   3897            24
# 1    Air India   Kolkata    Banglore            2   7662             1
# 2  Jet Airways     Delhi      Cochin            2  13882             9
# 3       IndiGo   Kolkata    Banglore            1   6218            12
# 4       IndiGo  Banglore   New Delhi            1  13302             1
#
#    Journey_Month  Journey_Year  Departure_Hour  Departure_Minute  \
# 0              3          2019              22                20
# 1              5          2019               5                50
# 2              6          2019               9                25
# 3              5          2019              18                 5
# 4              3          2019              16                50
#
#    Arrival_Hour  Arrival_Minute  Duration_hours  Duration_minutes
# 0             1              10               2                50
# 1            13              15               7                25
# 2             4              25              19                 0
# 3            23              30               5                25
# 4            21              35               4                45

# %% [markdown]
# # EDA on Data

# %%
airline_prices = df.groupby('Airline')['Price'].mean().reset_index()

# %%
plt.figure(figsize=(8,4))
sns.barplot(x='Price',y='Airline',data=airline_prices,palette="icefire")
plt.title("Average Price' of Flights by Airline",fontweight='bold',color='black',size=17,fontstyle='italic')
plt.xlabel('Price',size=15,fontweight='bold')
plt.ylabel('Airline',size=17,fontweight='bold')
plt.xticks(rotation=100)
plt.show()

# %%
plt.figure(figsize=(11,4))
sns.set_style('darkgrid')
sns.countplot(x='Destination',hue='Total_Stops',data=df,palette='copper_r')
plt.title('Flight Count to Each Destination by Number of Stops',fontweight='bold',color='black',size=16,fontstyle='italic')
plt.xlabel('Destination',size=15,fontweight='bold')
plt.ylabel('Flight Count',size=15,fontweight='bold')
plt.show()

# %%
duration_price = df.groupby('Duration_hours')['Price'].mean().reset_index()

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x='Duration_hours', y='Price', data=duration_price, color='blue')
plt.title('Average Price of Flights by Duration Hours',fontweight='bold',color='black',size=18,fontstyle='italic')
plt.xlabel('Duration Hours',size=17,fontweight='bold')
plt.ylabel('Price',size=17,fontweight='bold')
plt.grid(True)
plt.show()

# %%
month_price = df.groupby('Journey_Month')['Price'].mean().reset_index()

# %%
plt.figure(figsize=(10,4))
sns.set_style('whitegrid')
sns.lineplot(x='Journey_Month', y='Price', data=month_price, marker='o', color='red')
plt.title('Average Price of Flights by Month',fontweight='bold',color='black',size=18,fontstyle='italic')
plt.xlabel('Journey Month',size=15,fontweight='bold')
plt.ylabel('Average Price',size=15,fontweight='bold')
plt.xticks(month_price['Journey_Month'])
plt.grid(True)
plt.show()

# %%
#dummies= pd.get_dummies(df,drop_first=True,dtype="int")

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
en_data= ['Airline','Source','Destination']

# %%
ordinal= OrdinalEncoder()

# %%
df[en_data]= ordinal.fit_transform(df[en_data])

# %%
df
# Out:
#        Airline  Source  Destination  Total_Stops  Price  Journey_Date  \
# 0          3.0     0.0          5.0            0   3897            24
# 1          1.0     3.0          0.0            2   7662             1
# 2          4.0     2.0          1.0            2  13882             9
# 3          3.0     3.0          0.0            1   6218            12
# 4          3.0     0.0          5.0            1  13302             1
# ...        ...     ...          ...          ...    ...           ...
# 10678      0.0     3.0          0.0            0   4107             9
# 10679      1.0     3.0          0.0            0   4145            27
# 10680      4.0     0.0          2.0            0   7229            27
# 10681     10.0     0.0          5.0            0  12648             1
# 10682      1.0     2.0          1.0            2  11753             9
#
#        Journey_Month  Journey_Year  Departure_Hour  Departure_Minute  \
# 0                  3          2019              22                20
# 1                  5          2019               5                50
# 2                  6          2019               9                25
# 3                  5          2019              18                 5
# 4                  3          2019              16                50
# ...              ...           ...             ...               ...
# 10678              4          2019              19                55
# 10679              4          2019              20                45
# 10680              4          2019               8                20
# 10681              3          2019              11                30
# 10682              5          2019              10                55
#
#        Arrival_Hour  Arrival_Minute  Duration_hours  Duration_minutes
# 0                 1              10               2                50
# 1                13              15               7                25
# 2                 4              25              19                 0
# 3                23              30               5                25
# 4                21              35               4                45
# ...             ...             ...             ...               ...
# 10678            22              25               2                30
# 10679            23              20               2                35
# 10680            11              20               3                 0
# 10681            14              10               2                40
# 10682            19              15               8                20
#
# [10682 rows x 14 columns]

# %%
df.reset_index(inplace=True)

# %%
df.drop('index',axis=1,inplace=True)

# %%
x= df.drop('Price',axis=1)
y= df['Price']

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mn= MinMaxScaler()

# %%
cols= x.columns

# %%
x= mn.fit_transform(x)

# %%
x= pd.DataFrame(x,columns=cols)

# %%
x
# Out:
#         Airline  Source  Destination  Total_Stops  Journey_Date  \
# 0      0.272727    0.00          1.0         0.00      0.884615
# 1      0.090909    0.75          0.0         0.50      0.000000
# 2      0.363636    0.50          0.2         0.50      0.307692
# 3      0.272727    0.75          0.0         0.25      0.423077
# 4      0.272727    0.00          1.0         0.25      0.000000
# ...         ...     ...          ...          ...           ...
# 10677  0.000000    0.75          0.0         0.00      0.307692
# 10678  0.090909    0.75          0.0         0.00      1.000000
# 10679  0.363636    0.00          0.4         0.00      1.000000
# 10680  0.909091    0.00          1.0         0.00      0.000000
# 10681  0.090909    0.50          0.2         0.50      0.307692
#
#        Journey_Month  Journey_Year  Departure_Hour  Departure_Minute  \
# 0           0.000000           0.0        0.956522          0.363636
# 1           0.666667           0.0        0.217391          0.909091
# 2           1.000000           0.0        0.391304          0.454545
# 3           0.666667           0.0        0.782609          0.090909
# 4           0.000000           0.0        0.695652          0.909091
# ...              ...           ...             ...               ...
# 10677       0.333333           0.0        0.826087          1.000000
# 10678       0.333333           0.0        0.869565          0.818182
# 10679       0.333333           0.0        0.347826          0.363636
# 10680       0.000000           0.0        0.478261          0.545455
# 10681       0.666667           0.0        0.434783          1.000000
#
#        Arrival_Hour  Arrival_Minute  Duration_hours  Duration_minutes
# 0          0.043478        0.181818        0.042553          0.909091
# 1          0.565217        0.272727        0.148936          0.454545
# 2          0.173913        0.454545        0.404255          0.000000
# 3          1.000000        0.545455        0.106383          0.454545
# 4          0.913043        0.636364        0.085106          0.818182
# ...             ...             ...             ...               ...
# 10677      0.956522        0.454545        0.042553          0.545455
# 10678      1.000000        0.363636        0.042553          0.636364
# 10679      0.478261        0.363636        0.063830          0.000000
# 10680      0.608696        0.181818        0.042553          0.727273
# 10681      0.826087        0.272727        0.170213          0.363636
#
# [10682 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,random_state=45,test_size=0.2,shuffle=True)

# %%
print("shape of x_train:", x_train.shape)
print("shape of x_test:", x_test.shape)
print("shape of y_train:", y_train.shape)
print("shape of y_test:", y_test.shape)
# Out:
# shape of x_train: (8545, 13)
# shape of x_test: (2137, 13)
# shape of y_train: (8545,)
# shape of y_test: (2137,)

# %% [markdown]
# # statsmodels is a library used for estimating and analyzing statistical models.

# %%
import statsmodels.api as sm

# %%
x_train= sm.add_constant(x_train)

# %%
model = sm.OLS(y_train,x_train).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.446
# Model:                            OLS   Adj. R-squared:                  0.445
# Method:                 Least Squares   F-statistic:                     571.5
# Date:                Wed, 14 Aug 2024   Prob (F-statistic):               0.00
# Time:                        18:20:39   Log-Likelihood:                -81626.
# No. Observations:                8545   AIC:                         1.633e+05
# Df Residuals:                    8532   BIC:                         1.634e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             7088.9960    248.839     28.488      0.000    6601.211    7576.781
# Airline           2016.6897    177.602     11.355      0.000    1668.547    2364.833
# Source           -1271.2305    157.433     -8.075      0.000   -1579.837    -962.624
# Destination        471.5530    172.362      2.736      0.006     133.682     809.424
# Total_Stops       1.531e+04    336.418     45.496      0.000    1.46e+04     1.6e+04
# Journey_Date     -2203.3419    113.530    -19.408      0.000   -2425.887   -1980.797
# Journey_Month    -1428.7760    103.383    -13.820      0.000   -1631.431   -1226.120
# Journey_Year      4.634e-12   1.49e-13     31.140      0.000    4.34e-12    4.93e-12
# Departure_Hour     890.7469    149.416      5.962      0.000     597.856    1183.638
# Departure_Minute  -370.7031    110.116     -3.366      0.001    -586.558    -154.848
# Arrival_Hour       -97.6701    126.839     -0.770      0.441    -346.305     150.964
# Arrival_Minute    -345.8425    128.177     -2.698      0.007    -597.101     -94.584
# Duration_hours    3143.1697    307.112     10.235      0.000    2541.156    3745.184
# Duration_minutes  -640.7668    124.598     -5.143      0.000    -885.009    -396.525
# ==============================================================================
# Omnibus:                     6346.301   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           446433.057
# Skew:                           2.942   Prob(JB):                         0.00
# Kurtosis:                      37.918   Cond. No.                     1.37e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.57e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
x_train.drop("Arrival_Hour",axis=1,inplace=True)

# %%
model = sm.OLS(y_train,x_train).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.446
# Model:                            OLS   Adj. R-squared:                  0.445
# Method:                 Least Squares   F-statistic:                     623.4
# Date:                Wed, 14 Aug 2024   Prob (F-statistic):               0.00
# Time:                        18:20:39   Log-Likelihood:                -81627.
# No. Observations:                8545   AIC:                         1.633e+05
# Df Residuals:                    8533   BIC:                         1.634e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             7019.1833    231.730     30.290      0.000    6564.936    7473.430
# Airline           2017.8017    177.592     11.362      0.000    1669.679    2365.925
# Source           -1270.0697    157.422     -8.068      0.000   -1578.655    -961.485
# Destination        477.7970    172.167      2.775      0.006     140.308     815.286
# Total_Stops       1.531e+04    336.209     45.551      0.000    1.47e+04     1.6e+04
# Journey_Date     -2202.1292    113.516    -19.399      0.000   -2424.648   -1979.611
# Journey_Month    -1425.9411    103.315    -13.802      0.000   -1628.463   -1223.419
# Journey_Year      1.939e-12   7.91e-14     24.509      0.000    1.78e-12    2.09e-12
# Departure_Hour     888.8163    149.391      5.950      0.000     595.974    1181.659
# Departure_Minute  -375.4807    109.939     -3.415      0.001    -590.987    -159.974
# Arrival_Minute    -331.9487    126.898     -2.616      0.009    -580.700     -83.198
# Duration_hours    3134.5683    306.902     10.214      0.000    2532.967    3736.170
# Duration_minutes  -631.2783    123.984     -5.092      0.000    -874.317    -388.240
# ==============================================================================
# Omnibus:                     6346.252   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           446768.206
# Skew:                           2.942   Prob(JB):                         0.00
# Kurtosis:                      37.931   Cond. No.                     1.59e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.05e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
x_train.drop("Arrival_Minute",axis=1,inplace=True)

# %%
model = sm.OLS(y_train,x_train).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.445
# Model:                            OLS   Adj. R-squared:                  0.444
# Method:                 Least Squares   F-statistic:                     684.6
# Date:                Wed, 14 Aug 2024   Prob (F-statistic):               0.00
# Time:                        18:20:39   Log-Likelihood:                -81630.
# No. Observations:                8545   AIC:                         1.633e+05
# Df Residuals:                    8534   BIC:                         1.634e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             6870.2915    224.708     30.574      0.000    6429.810    7310.773
# Airline           2054.2957    177.104     11.599      0.000    1707.130    2401.462
# Source           -1292.7225    157.237     -8.221      0.000   -1600.946    -984.500
# Destination        483.6464    172.211      2.808      0.005     146.070     821.222
# Total_Stops       1.538e+04    335.521     45.825      0.000    1.47e+04     1.6e+04
# Journey_Date     -2197.4976    113.541    -19.354      0.000   -2420.065   -1974.930
# Journey_Month    -1397.9219    102.793    -13.599      0.000   -1599.422   -1196.422
# Journey_Year     -4.317e-11   8.46e-13    -50.997      0.000   -4.48e-11   -4.15e-11
# Departure_Hour     861.5701    149.078      5.779      0.000     569.340    1153.800
# Departure_Minute  -365.8068    109.914     -3.328      0.001    -581.265    -150.348
# Duration_hours    3138.6703    307.003     10.224      0.000    2536.871    3740.470
# Duration_minutes  -680.2504    122.604     -5.548      0.000    -920.585    -439.916
# ==============================================================================
# Omnibus:                     6341.478   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           444544.672
# Skew:                           2.940   Prob(JB):                         0.00
# Kurtosis:                      37.843   Cond. No.                     2.25e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.91e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
x_train
# Out:
#       const   Airline  Source  Destination  Total_Stops  Journey_Date  \
# 5612    1.0  0.545455    0.50          0.2         0.25      0.884615
# 2952    1.0  0.272727    0.75          0.0         0.00      0.192308
# 2889    1.0  0.363636    0.00          0.4         0.00      0.000000
# 6611    1.0  0.090909    0.75          0.0         0.50      0.538462
# 794     1.0  0.363636    0.50          0.2         0.50      0.653846
# ...     ...       ...     ...          ...          ...           ...
# 8772    1.0  0.727273    0.75          0.0         0.00      0.769231
# 163     1.0  0.272727    0.50          0.2         0.25      0.307692
# 6012    1.0  0.363636    0.75          0.0         0.25      0.423077
# 6558    1.0  0.272727    0.00          1.0         0.00      0.000000
# 7115    1.0  0.272727    0.50          0.2         0.25      0.769231
#
#       Journey_Month  Journey_Year  Departure_Hour  Departure_Minute  \
# 5612       1.000000           0.0        0.347826          0.818182
# 2952       0.666667           0.0        0.956522          0.272727
# 2889       0.666667           0.0        0.347826          0.363636
# 6611       0.666667           0.0        0.391304          0.454545
# 794        0.666667           0.0        0.565217          0.454545
# ...             ...           ...             ...               ...
# 8772       0.333333           0.0        0.956522          0.363636
# 163        0.666667           0.0        0.260870          0.909091
# 6012       0.666667           0.0        0.913043          0.181818
# 6558       0.000000           0.0        0.956522          0.363636
# 7115       0.000000           0.0        0.260870          0.727273
#
#       Duration_hours  Duration_minutes
# 5612        0.212766          0.545455
# 2952        0.042553          0.636364
# 2889        0.063830          0.000000
# 6611        0.170213          1.000000
# 794         0.617021          0.636364
# ...              ...               ...
# 8772        0.042553          0.363636
# 163         0.191489          0.363636
# 6012        0.255319          1.000000
# 6558        0.042553          0.909091
# 7115        0.297872          0.363636
#
# [8545 rows x 12 columns]

# %%
x_test= sm.add_constant(x_test)

# %%
x_test= x_test[x_train.columns]

# %%
x_test
# Out:
#        const   Airline  Source  Destination  Total_Stops  Journey_Date  \
# 6296     1.0  0.272727    0.25          0.8         0.00      0.769231
# 62       1.0  0.545455    0.50          0.2         0.25      0.076923
# 4165     1.0  0.363636    0.00          0.4         0.00      0.769231
# 10332    1.0  0.090909    0.75          0.0         0.50      0.538462
# 4131     1.0  0.363636    0.50          0.2         0.50      1.000000
# ...      ...       ...     ...          ...          ...           ...
# 2288     1.0  0.181818    0.50          0.2         0.25      0.192308
# 2642     1.0  0.363636    0.50          0.2         0.25      0.076923
# 1772     1.0  0.909091    0.00          0.4         0.00      0.769231
# 7775     1.0  0.545455    0.50          0.2         0.25      0.653846
# 3626     1.0  0.363636    0.75          0.0         0.25      0.307692
#
#        Journey_Month  Journey_Year  Departure_Hour  Departure_Minute  \
# 6296        0.000000           0.0        0.565217          0.363636
# 62          1.000000           0.0        0.347826          0.818182
# 4165        0.333333           0.0        0.347826          0.363636
# 10332       0.666667           0.0        0.391304          0.454545
# 4131        0.666667           0.0        0.391304          0.727273
# ...              ...           ...             ...               ...
# 2288        0.333333           0.0        0.304348          0.454545
# 2642        1.000000           0.0        0.739130          0.545455
# 1772        0.333333           0.0        0.739130          0.000000
# 7775        0.666667           0.0        0.260870          0.000000
# 3626        0.666667           0.0        0.260870          0.545455
#
#        Duration_hours  Duration_minutes
# 6296         0.042553          0.272727
# 62           0.212766          0.272727
# 4165         0.063830          0.000000
# 10332        0.659574          1.000000
# 4131         0.382979          0.818182
# ...               ...               ...
# 2288         0.127660          0.181818
# 2642         0.212766          1.000000
# 1772         0.042553          0.636364
# 7775         0.127660          0.636364
# 3626         0.234043          0.818182
#
# [2137 rows x 12 columns]

# %%
prediction= model.predict(x_test)

# %%
prediction
# Out:
# 6296      6105.899038
# 62       10200.737195
# 4165      6021.406510
# 10332    13220.791577
# 4131     12342.507859
#              ...
# 2288     10022.392281
# 2642      9769.402901
# 1772      7112.421314
# 7775      9108.816755
# 3626      9086.759013
# Length: 2137, dtype: float64

# %%
y_test
# Out:
# 6296      3384
# 62       12524
# 4165      7229
# 10332    13616
# 4131     13029
#          ...
# 2288      4201
# 2642     10262
# 1772      5613
# 7775      9794
# 3626     10844
# Name: Price, Length: 2137, dtype: int64

# %% [markdown]
# # To check Linear Regression Assumptions

# %%
plt.figure(figsize=(6,4))
plt.scatter(y_test,prediction,label='prediction',color="green")
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.histplot((y_test-prediction),bins=50,kde=True)
plt.show()

# %%
plt.figure(figsize=(5,4))
plt.scatter(df["Airline"],df["Price"])
plt.show()

# %%
plt.figure(figsize=(5,4))
plt.scatter(df["Destination"],df["Price"])
plt.show()

# %% [markdown]
# # Implementing Model

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
models = {
    'KNeighbors Regression': KNeighborsRegressor(n_neighbors=5,metric='manhattan'),
     'DecisionTreeRegression': DecisionTreeRegressor(),
    'RandomForestRegression': RandomForestRegressor(),
    'SVR': SVR()
}

# %%
from sklearn.metrics import r2_score
train_score={}
test_score={}
results=[]

for name, model in models.items():
    model.fit(x_train,y_train)
    y_pred= model.predict(x_test)
    
    train_score[name]= model.score(x_train,y_train)
    test_score[name]= model.score(x_test,y_test)
    
    r2= r2_score(y_test,y_pred)
   
    
    results.append({
        'Model': name,
        'Train_score': train_score[name],
        'Test_score': test_score[name],
        'R2_score': r2,
        
    })
result_df= pd.DataFrame(results)

# %%
result_df
# Out:
#                     Model  Train_score  Test_score  R2_score
# 0   KNeighbors Regression     0.843217    0.679241  0.679241
# 1  DecisionTreeRegression     0.970297    0.679686  0.679686
# 2  RandomForestRegression     0.955777    0.741446  0.741446
# 3                     SVR     0.016788    0.006774  0.006774

# %% [markdown]
# #  Using Hyperparameter Tuning

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
rfr= RandomForestRegressor()

# %%
rfr.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
grid= {
    'criterion':["squared_error", "absolute_error", "friedman_mse", "poisson"],
    'max_depth': [1,5,15,20],
    'max_leaf_nodes': [1,5,15,20],
    'min_samples_leaf': list(range(1,10)),
    'min_samples_split': list(range(1,10))
}

# %%
rscv= RandomizedSearchCV(estimator=rfr, param_distributions=grid, cv=5)

# %%
rscv.fit(x,y)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(),
#                    param_distributions={'criterion': ['squared_error',
#                                                       'absolute_error',
#                                                       'friedman_mse',
#                                                       'poisson'],
#                                         'max_depth': [1, 5, 15, 20],
#                                         'max_leaf_nodes': [1, 5, 15, 20],
#                                         'min_samples_leaf': [1, 2, 3, 4, 5, 6,
#                                                              7, 8, 9],
#                                         'min_samples_split': [1, 2, 3, 4, 5, 6,
#                                                               7, 8, 9]})

# %%
rscv.best_params_
# Out:
# {'min_samples_split': 4,
#  'min_samples_leaf': 3,
#  'max_leaf_nodes': 20,
#  'max_depth': 5,
#  'criterion': 'poisson'}

# %%
rscv.best_score_
# Out:
# np.float64(0.6798439766384862)

# %%
rfr= RandomForestRegressor(
            min_samples_split= 2,
             min_samples_leaf=1, max_leaf_nodes=20,max_depth=15,criterion='friedman_mse')

# %%
rfr.fit(x,y)
# Out:
# RandomForestRegressor(criterion='friedman_mse', max_depth=15, max_leaf_nodes=20)

# %%
rfr.score(x,y)
# Out:
# 0.7163918708989607
